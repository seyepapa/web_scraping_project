# %% [markdown]
# # WEB SCRAPING

# %% [markdown]
# Le web scraping est une technique qu'on utilise pour extraire de manière automatique des données souvent structurées qui se trouve sur une ou plusieurs pages d'un site web. Le web scraping peut se faire en utilisant un langage de programmation comme nous l'avons réalise dans ce projet. Nous avons utilisé le package beautefulSoup de Python pour la réalisation de ce projet. Mais il existe d'autre module qu'on peut utilisés tels selenium, scrapy, etc.

# %% [markdown]
# ## import des modules

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/'
r = requests.get(url)
html_doc = r.text
soup = BeautifulSoup(html_doc)

# %% [markdown]
# ## Pour obtenir le titre de la page html

# %%
print(soup.title.get_text())
# Out:
#         League table - Fast Track

# %% [markdown]
# # Pour voir comment notre page html est structurée on utilise la méthode prettify()

# %%
print(soup.prettify())
# Out:
# <!-- Template Name: League Table page
# -->
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html class="ie ie6 no-js" lang="en-GB"> <![endif]-->
# <!--[if IE 7 ]>    <html class="ie ie7 no-js" lang="en-GB"> <![endif]-->
# <!--[if IE 8 ]>    <html class="ie ie8 no-js" lang="en-GB"> <![endif]-->
# <!--[if IE 9 ]>    <html class="ie ie9 no-js" lang="en-GB"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="en-GB">
#  <!--<![endif]-->
#  <!-- the "no-js" class is for Modernizr. -->
#  <head id="live2-fasttrack-com">
#   <link data-minify="1" href="https://www.fasttrack.co.uk/wp-content/cache/min/1/cea6300e25ae12e4c4cd2ae75f253d92.css" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    League table - Fast Track
#   </title>
#   <meta content="League table - Fast Track" name="title"/>
#   <meta content="" name="description"/>
#   <meta content="" name="keyword"/>
#   <meta content="ZYBMlezF37FAeJwYQIBdbJtogbNm9zRcb4fCelYavj8" name="google-site-verification"/>
#   <!-- Speaking of Google, don't forget to set your site up: http://google.com/webmasters -->
#   <!-- Start of Google Analytics Code -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-37401296-1', 'auto');
# ga('set', 'anonymizeIp', true);
#   ga('send', 'pageview');
#   </script>
#   <!-- End of Google Analytics Code -->
#   <meta content="Fast Track" name="author"/>
#   <meta content="Copyright Fast Track 2011. All Rights Reserved." name="Copyright"/>
#   <!-- Dublin Core Metadata : http://dublincore.org/ -->
#   <meta content="Fast Track" name="DC.title"/>
#   <!--	<meta name="DC.subject" content="What you're about.">-->
#   <meta content="TWK" name="DC.creator"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/manifest.json" rel="manifest"/>
#   <link color="#5bbad5" href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/favicon.ico" rel="shortcut icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/favicon/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,700italic" rel="stylesheet" type="text/css"/>
#   <!-- CSS: screen, mobile & print are all in the same file -->
#   <link href="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/css/screen.css?ver=3.2" rel="stylesheet"/>
#   <link href="https://www.fasttrack.co.uk/xmlrpc.php" rel="pingback"/>
#   <style type="text/css">
#    .hiring-link {
#             display: inline-block;
#             position: relative;
#             top: -23px;
#             margin-right: 30px;
#         }
#
# 				.hiring-link-2 {
# 					margin-right: 40px;
# 				}
#
#         .hiring-link span a {
#             color: white;
#             font-size: 1.2em;
#         }
#
#         .hiring-link span a:hover {
#             color: #b1b1b1;
#         }
#
# 				#menu_button {
# 					margin-left: 30px
# 				}
#
#         @media only screen and (max-width: 700px) {
#             .hiring-link {
#                 display: none;
#             }
#         }
#
#         #wrap-search input[type="text"]:focus {
#             background: black !important;
#         }
#   </style>
#   <!-- ADD GA CODE HERE -->
#   <!-- This site is optimized with the Yoast SEO plugin v14.0.2 - https://yoast.com/wordpress/plugins/seo/ -->
#   <meta content="index, follow" name="robots"/>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>
#   <link href="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/" rel="canonical"/>
#   <meta content="en_GB" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="League table - Fast Track" property="og:title"/>
#   <meta content="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/" property="og:url"/>
#   <meta content="Fast Track" property="og:site_name"/>
#   <meta content="2019-10-28T14:26:58+00:00" property="article:modified_time"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@ST_FastTrack" name="twitter:creator"/>
#   <meta content="@ST_FastTrack" name="twitter:site"/>
#   <script class="yoast-schema-graph" type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.fasttrack.co.uk/#organization","name":"The Sunday Times Fast Track","url":"https://www.fasttrack.co.uk/","sameAs":["https://www.instagram.com/thesundaytimesfasttrack/","https://www.linkedin.com/company/sunday-times-fast-track/","https://twitter.com/ST_FastTrack"],"logo":{"@type":"ImageObject","@id":"https://www.fasttrack.co.uk/#logo","inLanguage":"en-GB","url":"https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-twitter-logo.png","width":480,"height":480,"caption":"The Sunday Times Fast Track"},"image":{"@id":"https://www.fasttrack.co.uk/#logo"}},{"@type":"WebSite","@id":"https://www.fasttrack.co.uk/#website","url":"https://www.fasttrack.co.uk/","name":"Fast Track","description":"","publisher":{"@id":"https://www.fasttrack.co.uk/#organization"},"potentialAction":[{"@type":"SearchAction","target":"https://www.fasttrack.co.uk/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"en-GB"},{"@type":"WebPage","@id":"https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/#webpage","url":"https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/","name":"League table - Fast Track","isPartOf":{"@id":"https://www.fasttrack.co.uk/#website"},"datePublished":"2015-12-03T16:53:49+00:00","dateModified":"2019-10-28T14:26:58+00:00","inLanguage":"en-GB","potentialAction":[{"@type":"ReadAction","target":["https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/"]}]}]}
#   </script>
#   <!-- / Yoast SEO plugin. -->
#   <link href="//js.hs-scripts.com" rel="dns-prefetch"/>
#   <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.fasttrack.co.uk\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.4.2"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var sdm_ajax_script = {"ajaxurl":"https:\/\/www.fasttrack.co.uk\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/plugins/simple-download-monitor/js/sdm_wp_scripts.js?ver=5.4.2" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/modernizr-2.6.2.min.js" type="text/javascript">
#   </script>
#   <link href="https://www.fasttrack.co.uk/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.fasttrack.co.uk/?p=359" rel="shortlink"/>
#   <link href="https://www.fasttrack.co.uk/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.fasttrack.co.uk%2Fleague-tables%2Ftech-track-100%2Fleague-table%2F" rel="alternate" type="application/json+oembed"/>
#   <link href="https://www.fasttrack.co.uk/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.fasttrack.co.uk%2Fleague-tables%2Ftech-track-100%2Fleague-table%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#   <!-- DO NOT COPY THIS SNIPPET! Start of Page Analytics Tracking for HubSpot WordPress plugin v7.30.4-->
#   <script type="text/javascript">
#    var _hsq = _hsq || [];
# 				_hsq.push(["setContentType", "standard-page"]);
#   </script>
#   <!-- DO NOT COPY THIS SNIPPET! End of Page Analytics Tracking for HubSpot WordPress plugin -->
#   <style type="text/css">
#    .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#   </style>
#   <link href="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-66x66.jpg" rel="icon" sizes="32x32"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" rel="icon" sizes="192x192"/>
#   <link href="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" rel="apple-touch-icon"/>
#   <meta content="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-favicon-300x300.jpg" name="msapplication-TileImage"/>
#  </head>
#  <body class="page-template page-template-tpl page-template-tpl-league-table page-template-tpltpl-league-table-php page page-id-359 page-child parent-pageid-159">
#   <div id="page-wrap">
#    <!-- not needed? up to you: http://camendesign.com/code/developpeurs_sans_frontieres -->
#    <nav class="navbar navbar-fixed-top">
#     <div class="container-fluid">
#      <div class="row align-items-center">
#       <div class="col text-left">
#        <a class="navbar-brand active d-md-none" href="https://www.fasttrack.co.uk">
#         Tech Track 100
#        </a>
#        <a class="navbar-brand fast-track active d-none d-md-block" href="https://www.fasttrack.co.uk">
#         FAST TRACK
#        </a>
#       </div>
#       <div class="col-auto text-right">
#        <div class="navbar-right">
#         <div class="hiring-link hiring-link-1">
#          <span>
#           <a href="https://www.fasttrack.co.uk/covid-19-update/">
#            COVID-19 update
#           </a>
#          </span>
#         </div>
#         <div class="hiring-link hiring-link-2">
#          <span>
#           <a href="https://www.fasttrack.co.uk/about-us/careers/">
#            We're hiring
#           </a>
#          </span>
#         </div>
#         <div id="wrap-search">
#          <form action="https://www.fasttrack.co.uk" autocomplete="on" id="searchform" method="get" name="searchbar_form">
#           <input name="post_type[]" type="hidden" value="company_profile"/>
#           <input id="search" name="s" placeholder="Company search..." type="text"/>
#           <input id="search_submit" type="submit" value="Rechercher"/>
#          </form>
#         </div>
#         <div id="menu_button">
#          <span>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="side_menu">
#       <ul>
#        <li class="list-id-4">
#         <a href="https://www.fasttrack.co.uk/">
#          Home
#         </a>
#        </li>
#        <li class="list-id-29125">
#         <a href="https://www.fasttrack.co.uk/blog/">
#          Blog
#         </a>
#        </li>
#        <li class="list-id-156">
#         League tables
#         <ul>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/">
#            Fast Track 100
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/awards-dinners/">
#              Awards dinner
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/ones-to-watch/">
#              Disruptors/Ones to Watch
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/alumni/">
#              Alumni dinners
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/">
#            SME Export Track 100
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/awards/">
#              Awards dinner
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">
#            Tech Track 100
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/awards/">
#              Awards dinner
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/ones-to-watch/">
#              Green Tech/Ones to Watch
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/alumni/">
#              Alumni dinners
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/">
#            International Track 200
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/awards-dinners/">
#              Awards dinner
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/alumni/">
#              Alumni dinners
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/">
#            Profit Track 100
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/awards-dinners/">
#              Awards dinner
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/ones-to-watch/">
#              Ones to Watch
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/alumni/">
#              Alumni dinners
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/">
#            Top Track 250
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/awards/">
#              Awards dinner
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/top-track-250-ones-to-watch/">
#              Ones to Watch
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/alumni/">
#              Alumni dinners
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-dropdown">
#           <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/">
#            Top Track 100
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/league-table/">
#              League table
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/supplement/">
#              Supplement &amp; research
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/awards/">
#              Directors' dinners
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/nominate-a-company/">
#              Nominate a company
#             </a>
#            </li>
#            <li>
#             <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/sponsorship/">
#              Sponsorship
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </li>
#        <li class="list-id-172 menu-dropdown">
#         <a href="https://www.fasttrack.co.uk/about-us/">
#          About us
#         </a>
#         <ul>
#          <li>
#           <a href="https://www.fasttrack.co.uk/about-us/">
#           </a>
#          </li>
#          <li class="list-id-172-712">
#           <a href="https://www.fasttrack.co.uk/about-us/the-team/">
#            The team
#           </a>
#          </li>
#          <li class="list-id-172-228">
#           <a href="https://www.fasttrack.co.uk/about-us/careers/">
#            Careers
#           </a>
#          </li>
#          <li class="list-id-172-4192">
#           <a href="https://www.fasttrack.co.uk/about-us/charity/">
#            Charity
#           </a>
#          </li>
#          <li class="list-id-172-20661">
#           <a href="https://www.fasttrack.co.uk/about-us/data-partners/">
#            Data partners
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="list-id-174">
#         <a href="https://www.fasttrack.co.uk/nominate-a-company/">
#          Nominate a company
#         </a>
#        </li>
#        <li class="list-id-176">
#         <a href="https://www.fasttrack.co.uk/sponsorship/">
#          Sponsorship
#         </a>
#        </li>
#        <li class="list-id-178 menu-dropdown">
#         <a href="https://www.fasttrack.co.uk/media-and-logos/">
#          Media and logos
#         </a>
#         <ul>
#          <li>
#           <a href="https://www.fasttrack.co.uk/media-and-logos/">
#            Videos
#           </a>
#          </li>
#          <li class="list-id-178-4196">
#           <a href="https://www.fasttrack.co.uk/media-and-logos/press-releases/">
#            Press releases
#           </a>
#          </li>
#          <li class="list-id-178-4198">
#           <a href="https://www.fasttrack.co.uk/media-and-logos/downloads/">
#            Downloads and logos
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="list-id-180">
#         <a href="https://www.fasttrack.co.uk/contact-us/">
#          Contact us
#         </a>
#        </li>
#       </ul>
#       <a href="https://www.linkedin.com/company/sunday-times-fast-track" target="_blank">
#        <img alt="linkedIn" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/linkedin_circle_icon.png"/>
#       </a>
#       <a href="https://twitter.com/ST_FastTrack" target="_blank">
#        <img alt="twitter" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/twitter_circle_icon.png"/>
#       </a>
#       <a href="https://www.instagram.com/thesundaytimesfasttrack" target="_blank">
#        <img alt="instagram" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/instagram_circle_icon.png" style="width: 40px; height: 35px;"/>
#       </a>
#      </div>
#     </div>
#    </nav>
#    <div class="" id="content-wrap">
#     <section class="league_header d-none d-md-block">
#      <div class="main-title-header">
#       Tech Track 100
#      </div>
#      <div class="container">
#       <div class="row justify-content-between">
#        <div class="col-sm-4">
#         <img src="https://www.fasttrack.co.uk/wp-content/uploads/TechTrack100-logo-masthead-20th-anniversary-e1586342340544.png" style="padding-bottom: 4px;"/>
#        </div>
#        <div class="col-sm-8 text-right">
#         <div class="title_sponsor">
#          <a href="https://www.fasttrack.co.uk/sponsor-profiles/sage/">
#           <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/Sage-1.png');">
#           </div>
#          </a>
#         </div>
#         <div class="supported">
#          <a href="https://www.fasttrack.co.uk/sponsor-profiles/barclays/">
#           <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/Barclays.png');" title="">
#           </div>
#          </a>
#         </div>
#         <div class="supported">
#          <a href="https://www.fasttrack.co.uk/sponsor-profiles/bdo/">
#           <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/bdo.png');" title="">
#           </div>
#          </a>
#         </div>
#         <div class="supported">
#          <a href="https://www.fasttrack.co.uk/sponsor-profiles/bgf/">
#           <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/BGF-1.png');" title="">
#           </div>
#          </a>
#         </div>
#         <div class="supported">
#          <a href="https://www.fasttrack.co.uk/sponsor-profiles/n1-singer/">
#           <div class="image" style="background-image: url('https://www.fasttrack.co.uk/wp-content/uploads/N1-Singer.png');" title="">
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="league_navigation">
#       <div class="mobile-league-btn">
#        Menu
#       </div>
#       <ul>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">
#          Overview
#         </a>
#        </li>
#        <li>
#         <a class="active" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/">
#          League table
#         </a>
#        </li>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/supplement/">
#          Supplement &amp; research
#         </a>
#        </li>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/awards/">
#          Awards dinner
#         </a>
#        </li>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/ones-to-watch/">
#          Green Tech/Ones to Watch
#         </a>
#        </li>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/alumni/">
#          Alumni dinners
#         </a>
#        </li>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/nominate-a-company/">
#          Nominate a company
#         </a>
#        </li>
#        <li>
#         <a class="" href="https://www.fasttrack.co.uk/league-tables/tech-track-100/sponsorship/">
#          Sponsorship
#         </a>
#        </li>
#       </ul>
#      </div>
#     </section>
#     <div class="strip-padding">
#      <div class="container">
#       <article class="post" id="post-359">
#        <h1 class="text-center red-color">
#         Tech Track 100 league table
#         <div class="dropdown">
#          <button class="dropbtn button skew_forward">
#           2019
#          </button>
#          <div class="dropdown-content">
#           <a href="?leagueyear=2019">
#            2019
#           </a>
#           <a href="?leagueyear=2018">
#            2018
#           </a>
#           <a href="?leagueyear=2017">
#            2017
#           </a>
#           <a href="?leagueyear=2016">
#            2016
#           </a>
#           <a href="?leagueyear=2015">
#            2015
#           </a>
#           <a href="?leagueyear=2014">
#            2014
#           </a>
#           <a href="?leagueyear=2013">
#            2013
#           </a>
#           <a href="?leagueyear=2012">
#            2012
#           </a>
#           <a href="?leagueyear=2011">
#            2011
#           </a>
#           <a href="?leagueyear=2010">
#            2010
#           </a>
#           <a href="?leagueyear=2009">
#            2009
#           </a>
#           <a href="?leagueyear=2008">
#            2008
#           </a>
#           <a href="?leagueyear=2007">
#            2007
#           </a>
#           <a href="?leagueyear=2006">
#            2006
#           </a>
#           <a href="?leagueyear=2005">
#            2005
#           </a>
#           <a href="?leagueyear=2004">
#            2004
#           </a>
#           <a href="?leagueyear=2003">
#            2003
#           </a>
#           <a href="?leagueyear=2002">
#            2002
#           </a>
#           <a href="?leagueyear=2001">
#            2001
#           </a>
#          </div>
#         </div>
#        </h1>
#       </article>
#       <!--				Pull in data from the current year selected in page -->
#       <div class="responsive-tabble-wrapper">
#        <table class="tableSorter2">
#         <thead>
#          <tr>
#           <th>
#            Rank
#           </th>
#           <th>
#            Company
#           </th>
#           <th class="">
#            Location
#           </th>
#           <th class="no-word-wrap">
#            Year end
#           </th>
#           <th class="" style="text-align:right;">
#            Annual sales rise over 3 years
#           </th>
#           <th class="" style="text-align:right;">
#            Latest sales £000s
#           </th>
#           <th class="" style="text-align:right;">
#            Staff
#           </th>
#           <th class="">
#            Comment
#           </th>
#           <!--				<th>FYE</th>-->
#          </tr>
#         </thead>
#         <tbody>
#          <tr>
#           <td>
#            1
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/revolut-2/">
#             <span class="company-name">
#              Revolut
#             </span>
#            </a>
#            Digital banking services provider
#           </td>
#           <td>
#            East London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            507.56%
#           </td>
#           <td style="text-align:right;">
#            *58,300
#           </td>
#           <td style="text-align:right;">
#            700
#           </td>
#           <td>
#            Valued at $1.7bn in 2018 and reported to be raising an additional $500m this year that could value it at $5bn
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            2
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/bizuma-3/">
#             <span class="company-name">
#              Bizuma
#             </span>
#            </a>
#            B2B e-commerce platform
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Mar 19
#           </td>
#           <td style="text-align:right;">
#            315.18%
#           </td>
#           <td style="text-align:right;">
#            *26,414
#           </td>
#           <td style="text-align:right;">
#            114
#           </td>
#           <td>
#            Connects wholesale buyers and sellers from over 50 countries
#           </td>
#           <!--						<td>Mar 19</td>-->
#          </tr>
#          <tr>
#           <td>
#            3
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/global-e-2/">
#             <span class="company-name">
#              Global-e
#             </span>
#            </a>
#            Cross-border ecommerce solutions
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            303.09%
#           </td>
#           <td style="text-align:right;">
#            29,297
#           </td>
#           <td style="text-align:right;">
#            28
#           </td>
#           <td>
#            Its technology helps ecommerce retailers localise their websites in more than 200 markets
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            4
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/jungle-creations/">
#             <span class="company-name">
#              Jungle Creations
#             </span>
#            </a>
#            Social media &amp; ecommerce services
#           </td>
#           <td>
#            East London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            302.53%
#           </td>
#           <td style="text-align:right;">
#            *15,972
#           </td>
#           <td style="text-align:right;">
#            159
#           </td>
#           <td>
#            Launched the first-ever delivery-only restaurant born from social media
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            5
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/oxford-nanopore-technologies-2/">
#             <span class="company-name">
#              Oxford Nanopore Technologies
#             </span>
#            </a>
#            DNA analysis technology
#           </td>
#           <td>
#            Oxford
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            251.87%
#           </td>
#           <td style="text-align:right;">
#            *32,500
#           </td>
#           <td style="text-align:right;">
#            439
#           </td>
#           <td>
#            Has raised £451m in funding and was valued at £1.5bn last year
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            6
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/lendable/">
#             <span class="company-name">
#              Lendable
#             </span>
#            </a>
#            Consumer lending platform
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            242.98%
#           </td>
#           <td style="text-align:right;">
#            *19,366
#           </td>
#           <td style="text-align:right;">
#            44
#           </td>
#           <td>
#            Founder moved to the UK from Germany to start the firm, citing a more favourable financial market
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            7
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/verve-2/">
#             <span class="company-name">
#              Verve
#             </span>
#            </a>
#            Marketing software developer
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            235.72%
#           </td>
#           <td style="text-align:right;">
#            *21,940
#           </td>
#           <td style="text-align:right;">
#            230
#           </td>
#           <td>
#            Has implemented full salary transparency in order to combat the gender pay gap
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            8
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/onfido-2/">
#             <span class="company-name">
#              Onfido
#             </span>
#            </a>
#            Identity verification software
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            209.15%
#           </td>
#           <td style="text-align:right;">
#            *18,591
#           </td>
#           <td style="text-align:right;">
#            240
#           </td>
#           <td>
#            Has opened offices in the US, Europe, India and Singapore to service its 1,500 customers
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            9
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/reverse-media-group/">
#             <span class="company-name">
#              Reverse Media Group
#             </span>
#            </a>
#            Digital publishing agency
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Jul 18
#           </td>
#           <td style="text-align:right;">
#            208.10%
#           </td>
#           <td style="text-align:right;">
#            *7,606
#           </td>
#           <td style="text-align:right;">
#            15
#           </td>
#           <td>
#            Originally started as an animal onesie clothing company before pivoting to online publishing
#           </td>
#           <!--						<td>Jul 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            10
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/rebound-returns/">
#             <span class="company-name">
#              Rebound Returns
#             </span>
#            </a>
#            Ecommerce returns technology
#           </td>
#           <td>
#            Telford
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            191.08%
#           </td>
#           <td style="text-align:right;">
#            *16,659
#           </td>
#           <td style="text-align:right;">
#            21
#           </td>
#           <td>
#            Its platform handles more than 35m online returns transactions every year
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            11
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/clearscore-2/">
#             <span class="company-name">
#              ClearScore
#             </span>
#            </a>
#            Credit-checking technology developer
#           </td>
#           <td>
#            South London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            177.20%
#           </td>
#           <td style="text-align:right;">
#            *42,702
#           </td>
#           <td style="text-align:right;">
#            135
#           </td>
#           <td>
#            In 2018, £90m worth of mortgages were secured through its site
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            12
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/spoke/">
#             <span class="company-name">
#              SPOKE
#             </span>
#            </a>
#            Online menswear supplier
#           </td>
#           <td>
#            Richmond
#           </td>
#           <td>
#            Oct 18
#           </td>
#           <td style="text-align:right;">
#            177.10%
#           </td>
#           <td style="text-align:right;">
#            *5,566
#           </td>
#           <td style="text-align:right;">
#            36
#           </td>
#           <td>
#            Its technology helps customers find the right fit out of 200 clothing size options in just 60 seconds
#           </td>
#           <!--						<td>Oct 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            13
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/fsb/">
#             <span class="company-name">
#              FSB
#             </span>
#            </a>
#            Gambling platform
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            175.54%
#           </td>
#           <td style="text-align:right;">
#            *23,945
#           </td>
#           <td style="text-align:right;">
#            93
#           </td>
#           <td>
#            Has moved into William Hill's old R&amp;D offices in Shoreditch
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            14
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/decibel/">
#             <span class="company-name">
#              Decibel
#             </span>
#            </a>
#            Customer experience technology
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Jun 18
#           </td>
#           <td style="text-align:right;">
#            165.81%
#           </td>
#           <td style="text-align:right;">
#            5,387
#           </td>
#           <td style="text-align:right;">
#            68
#           </td>
#           <td>
#            Uses AI and machine learning to detect consumers’ feelings of confusion, frustration and engagement
#           </td>
#           <!--						<td>Jun 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            15
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/miss-group/">
#             <span class="company-name">
#              Miss Group
#             </span>
#            </a>
#            Web hosting provider
#           </td>
#           <td>
#            Manchester
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            162.06%
#           </td>
#           <td style="text-align:right;">
#            *6,925
#           </td>
#           <td style="text-align:right;">
#            55
#           </td>
#           <td>
#            Has made four acquisitions in the last year, with £19.4m investment from growth-capital firm BGF
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            16
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/complyadvantage-2/">
#             <span class="company-name">
#              ComplyAdvantage
#             </span>
#            </a>
#            Anti-money laundering database
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Mar 19
#           </td>
#           <td style="text-align:right;">
#            160.61%
#           </td>
#           <td style="text-align:right;">
#            *5,981
#           </td>
#           <td style="text-align:right;">
#            165
#           </td>
#           <td>
#            Its platform helps 450 customers in 45 countries address compliance issues
#           </td>
#           <!--						<td>Mar 19</td>-->
#          </tr>
#          <tr>
#           <td>
#            17
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/ota-insight-2/">
#             <span class="company-name">
# ...
#           </td>
#           <td style="text-align:right;">
#            53.02%
#           </td>
#           <td style="text-align:right;">
#            *61,022
#           </td>
#           <td style="text-align:right;">
#            299
#           </td>
#           <td>
#            Uses proprietary algorithms and warehouse automation to increase accuracy in medicine dispensing
#           </td>
#           <!--						<td>Mar 19</td>-->
#          </tr>
#          <tr>
#           <td>
#            92
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/adaptavist/">
#             <span class="company-name">
#              Adaptavist
#             </span>
#            </a>
#            IT consultancy
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Sep 18
#           </td>
#           <td style="text-align:right;">
#            52.46%
#           </td>
#           <td style="text-align:right;">
#            *26,704
#           </td>
#           <td style="text-align:right;">
#            162
#           </td>
#           <td>
#            Says it works with more than half of Fortune 500 companies
#           </td>
#           <!--						<td>Sep 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            93
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/alternative-airlines/">
#             <span class="company-name">
#              Alternative Airlines
#             </span>
#            </a>
#            Flight booking website
#           </td>
#           <td>
#            Surrey
#           </td>
#           <td>
#            Oct 18
#           </td>
#           <td style="text-align:right;">
#            51.49%
#           </td>
#           <td style="text-align:right;">
#            *9,985
#           </td>
#           <td style="text-align:right;">
#            30
#           </td>
#           <td>
#            Offers mobile payment solutions for customers from developing countries
#           </td>
#           <!--						<td>Oct 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            94
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/biosite-systems-2/">
#             <span class="company-name">
#              Biosite Systems
#             </span>
#            </a>
#            Workforce management software
#           </td>
#           <td>
#            Solihull
#           </td>
#           <td>
#            Jul 18
#           </td>
#           <td style="text-align:right;">
#            51.33%
#           </td>
#           <td style="text-align:right;">
#            9,756
#           </td>
#           <td style="text-align:right;">
#            165
#           </td>
#           <td>
#            Its technology is used on 1,000 construction sites, including Hinkley Point C nuclear power station
#           </td>
#           <!--						<td>Jul 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            95
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/justpark-2/">
#             <span class="company-name">
#              JustPark
#             </span>
#            </a>
#            Smart parking provider
#           </td>
#           <td>
#            North London
#           </td>
#           <td>
#            Mar 19
#           </td>
#           <td style="text-align:right;">
#            50.70%
#           </td>
#           <td style="text-align:right;">
#            *24,285
#           </td>
#           <td style="text-align:right;">
#            70
#           </td>
#           <td>
#            Over 3m drivers use its app to find car parking spaces across the UK
#           </td>
#           <!--						<td>Mar 19</td>-->
#          </tr>
#          <tr>
#           <td>
#            96
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/worldremit-4/">
#             <span class="company-name">
#              WorldRemit
#             </span>
#            </a>
#            Currency transfer provider
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            50.26%
#           </td>
#           <td style="text-align:right;">
#            *90,965
#           </td>
#           <td style="text-align:right;">
#            615
#           </td>
#           <td>
#            Is valued at more than $900m, having raised more than $375m since 2010
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            97
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/e3d-online-2/">
#             <span class="company-name">
#              E3D Online
#             </span>
#            </a>
#            3D printer developer
#           </td>
#           <td>
#            Oxfordshire
#           </td>
#           <td>
#            Apr 19
#           </td>
#           <td style="text-align:right;">
#            50.10%
#           </td>
#           <td style="text-align:right;">
#            *6,900
#           </td>
#           <td style="text-align:right;">
#            41
#           </td>
#           <td>
#            Has grown its exports to account for 75% of its total sales
#           </td>
#           <!--						<td>Apr 19</td>-->
#          </tr>
#          <tr>
#           <td>
#            98
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/parentpay-2/">
#             <span class="company-name">
#              Parentpay
#             </span>
#            </a>
#            School payment services provider
#           </td>
#           <td>
#            Coventry
#           </td>
#           <td>
#            Nov 18
#           </td>
#           <td style="text-align:right;">
#            49.97%
#           </td>
#           <td style="text-align:right;">
#            *30,400
#           </td>
#           <td style="text-align:right;">
#            210
#           </td>
#           <td>
#            Bought Dutch rival WIS in 2018, gaining access to 85% of the secondary school market in the Netherlands
#           </td>
#           <!--						<td>Nov 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            99
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/victor-6/">
#             <span class="company-name">
#              Victor
#             </span>
#            </a>
#            Online private jet hire
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            49.56%
#           </td>
#           <td style="text-align:right;">
#            *55,100
#           </td>
#           <td style="text-align:right;">
#            100
#           </td>
#           <td>
#            Counts Sir Elton John among its investors
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#          <tr>
#           <td>
#            100
#           </td>
#           <td>
#            <a href="https://www.fasttrack.co.uk/company_profile/dianomi-5/">
#             <span class="company-name">
#              Dianomi
#             </span>
#            </a>
#            Financial marketing platform
#           </td>
#           <td>
#            Central London
#           </td>
#           <td>
#            Dec 18
#           </td>
#           <td style="text-align:right;">
#            49.21%
#           </td>
#           <td style="text-align:right;">
#            *14,615
#           </td>
#           <td style="text-align:right;">
#            27
#           </td>
#           <td>
#            Works with eight of the top 10 global asset managers
#           </td>
#           <!--						<td>Dec 18</td>-->
#          </tr>
#         </tbody>
#        </table>
#       </div>
#       <div class="row">
#        <div class="col-md-8 legend">
#         <p>
#          <span data-sheets-userformat='[null,null,12736,null,null,null,null,null,null,0,0,0,null,null,null,"Calibri",11]' data-sheets-value='[null,2,"* supplied by company \u2021 annualised figure"]'>
#           * supplied by company
#          </span>
#          †
#          <span data-sheets-userformat='[null,null,12736,null,null,null,null,null,null,0,0,0,null,null,null,"Calibri",11]' data-sheets-value='[null,2,"* supplied by company \u2021 annualised figure"]'>
#           annualised figure
#          </span>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <section class="normal-padding d-md-none footer-sponsors">
#      <div class="container">
#       <div class="row justify-content-center">
#        <div class="col-12">
#         <h2>
#          Sponsors
#         </h2>
#        </div>
#        <div class="col-6 text-center">
#         <a href="https://www.fasttrack.co.uk/sponsor-profiles/sage/">
#          <img src="https://www.fasttrack.co.uk/wp-content/uploads/Sage-1.png"/>
#         </a>
#        </div>
#        <div class="col-6 text-center">
#         <a href="https://www.fasttrack.co.uk/sponsor-profiles/barclays/">
#          <img src="https://www.fasttrack.co.uk/wp-content/uploads/Barclays.png"/>
#         </a>
#        </div>
#        <div class="col-6 text-center">
#         <a href="https://www.fasttrack.co.uk/sponsor-profiles/bdo/">
#          <img src="https://www.fasttrack.co.uk/wp-content/uploads/bdo.png"/>
#         </a>
#        </div>
#        <div class="col-6 text-center">
#         <a href="https://www.fasttrack.co.uk/sponsor-profiles/bgf/">
#          <img src="https://www.fasttrack.co.uk/wp-content/uploads/BGF-1.png"/>
#         </a>
#        </div>
#        <div class="col-6 text-center">
#         <a href="https://www.fasttrack.co.uk/sponsor-profiles/n1-singer/">
#          <img src="https://www.fasttrack.co.uk/wp-content/uploads/N1-Singer.png"/>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="mobile-only text-center" style="margin-top: 20px;">
#       <a class="button skew_forward" href="/league-tables/league-table/sponsorship/">
#        Sponsorship
#       </a>
#      </div>
#     </section>
#    </div>
#   </div>
#   <!-- END DIV MAIN CONTENT -->
#   <div class="site-footer">
#    <div class="container">
#     <div class="row">
#      <div class="col-sm-3 d-none d-md-block">
#       <img class="footer-logo" src="https://www.fasttrack.co.uk/wp-content/uploads/Fast-Track-logo-white-strapline.png"/>
#      </div>
#      <div class="col-sm-4 col-md-3 col-6">
#       <h5>
#        League tables
#       </h5>
#       <ul>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/fast-track-100/">
#          Fast Track 100
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/sme-export-track-100/">
#          SME Export Track 100
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/tech-track-100/">
#          Tech Track 100
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/international-track-200/">
#          International Track 200
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/profit-track-100/">
#          Profit Track 100
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/top-track-250/">
#          Top Track 250
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/league-tables/top-track-100/">
#          Top Track 100
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-sm-4 col-md-3 col-6">
#       <h5>
#        Further info
#       </h5>
#       <ul>
#        <li>
#         <a href="https://www.fasttrack.co.uk/about-us/">
#          About us
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/nominate-a-company/">
#          Nominate a company
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/sponsorship/">
#          Sponsorship
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/media-and-logos/">
#          Media and logos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.fasttrack.co.uk/contact-us/">
#          Contact us
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-sm-4 col-md-3 col-xs-12">
#       <h5>
#        Other
#       </h5>
#       <ul>
#        <li>
#         <a href="https://www.fasttrack.co.uk/privacy-cookies-policy/">
#          Privacy &amp; cookies policy
#         </a>
#        </li>
#       </ul>
#       <div class="social-links">
#        <a href="https://www.linkedin.com/company/sunday-times-fast-track" target="_blank">
#         <img alt="linkedIn" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/linkedin.svg"/>
#        </a>
#        <a href="https://twitter.com/ST_FastTrack" target="_blank">
#         <img alt="twitter" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/twitter.svg"/>
#        </a>
#        <a href="https://www.instagram.com/thesundaytimesfasttrack" target="_blank">
#         <img alt="instagram" src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/img/instagram_circle_icon.png"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="site-footer__copyright">
#     <div class="container">
#      <div class="row">
#       <div class="col-sm-6 text-center text-sm-left">
#        Copyright Fast Track © 2020
#       </div>
#       <div class="col-sm-6 text-center text-sm-right">
#        <a href="http://www.thewebkitchen.co.uk/" target="_blank">
#         Web design
#        </a>
#        by
#        <a href="http://www.thewebkitchen.co.uk/">
#         TWK
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    _linkedin_data_partner_id = "323508";
#   </script>
#   <script type="text/javascript">
#    (function(){var s = document.getElementsByTagName("script")[0];
#
# var b = document.createElement("script");
#
# b.type = "text/javascript";b.async = true;
#
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#
# s.parentNode.insertBefore(b, s);})();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=323508&amp;fmt=gif" style="display:none;" width="1"/>
#   </noscript>
#   <!-- JS ARE LOADED HERE WITH FUNCTION.PHP -->
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var leadin_wordpress = {"userRole":"visitor","pageType":"page","leadinPluginVersion":"7.30.4"};
# /* ]]> */
#   </script>
#   <script async="" defer="" id="hs-script-loader" src="//js.hs-scripts.com/6844576.js?integration=WordPress" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/bootstrap.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/owl.carousel.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/slick.js" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/jquery.magnific-popup.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/lightbox.js" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-content/themes/fast_track/assets/js/script.js?ver=7" type="text/javascript">
#   </script>
#   <script src="https://www.fasttrack.co.uk/wp-includes/js/wp-embed.min.js?ver=5.4.2" type="text/javascript">
#   </script>
#   <!-- Wordpress-friendly way via functions.php -->
#   <!-- Asynchronous google analytics; this is the official snippet.
# 		 Replace UA-XXXXXX-XX with your site's ID and uncomment to enable.
#
# 	<script>
#
# 	  var _gaq = _gaq || [];
# 	  _gaq.push(['_setAccount', 'UA-XXXXXX-XX']);
# 	  _gaq.push(['_trackPageview']);
#
# 	  (function() {
# 	    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
#
# 	</script>
# 	-->
#  </body>
# </html>

# %% [markdown]
# # Les données que nous voulons extraire se trouve sur l'élément table. Donc on utilise la méthode find_all()

# %%
table = soup.find_all('table', attrs={'class': "tableSorter2"})

# %% [markdown]
# ## Dans l'élément table, nous avons des élément table header (th) qui vont contenir les noms des colonnes des données.

# %%
columns = soup.find_all('th')

# %%
columns
# Out:
# [<th>Rank</th>,
#  <th>Company</th>,
#  <th class="">Location</th>,
#  <th class="no-word-wrap">Year end</th>,
#  <th class="" style="text-align:right;">Annual sales rise over 3 years</th>,
#  <th class="" style="text-align:right;">Latest sales £000s</th>,
#  <th class="" style="text-align:right;">Staff</th>,
#  <th class="">Comment</th>]

# %%
col_name = []
for th in columns:
    col_name.append(th.get_text())

# %%
col_name
# Out:
# ['Rank',
#  'Company',
#  'Location',
#  'Year end',
#  'Annual sales rise over 3 years',
#  'Latest sales £000s',
#  'Staff',
#  'Comment']

# %% [markdown]
# ## Les données se trouvent sur l'élément table data. Pour avoir l'ensemble des données on applique la méthode find_all() sur l'élément td.

# %%
dt = soup.find_all('td')

# %% [markdown]
# ## Un peu de maths avec list comprehion

# %% [markdown]
# Les contenus des colonnes se trouves à des positions particulières. Par exemple si on prend la colonne 'Rank' qui se  trouve à indice 0, à'indice 8 puis à l'indece 16 ainsi de suite. Donc ce que nous constatons c'est que le reste de la division euclidienne de l'indice  des données de cette colonne par 8 est égal 0. De même que la colonne 'Company' dont ses données se trouvent sur l'indice 1, indice 9, indice 17 ainsi de suite. Donc le reste de la divion euclidienne de ces indices par 8 est 1. On fait de même avec les autres colonnes

# %%
rank = [dt[i].getText() for i in range(len(dt)) if i%8==0]
company = [dt[i].getText() for i in range(len(dt)) if i%8==1]
location = [dt[i].getText() for i in range(len(dt)) if i%8==2]
yearend = [dt[i].getText() for i in range(len(dt)) if i%8==3]
salesrise = [dt[i].getText() for i in range(len(dt)) if i%8==4]
sales = [dt[i].getText() for i in range(len(dt)) if i%8==5]
staff = [dt[i].getText() for i in range(len(dt)) if i%8==6]
comments = [dt[i].getText() for i in range(len(dt)) if i%8==7]

# %%
# data1 est une liste de liste. c'est une variable qui stocke les données de nos colonnes
data1 = [rank, company, location, yearend, salesrise, sales, staff, comments] 
# la variable dictionnaire est utisée ici pour stocker les données dans un dictionnaire. Les clés vont être les 
# noms des colonnes de notre jeu de données et las valeurs sont les lignes.
dictionnaire = dict([(col_name[i], data1[i]) for i in range(len(col_name))])

# %% [markdown]
# ## Transormation de notre dicyionnaire en un dataframe

# %% [markdown]
#  On utilie le module pandas de Python. Pandas est un module très intéressant qu'on utilise souvent pour travailler avec les données structurées ou semi-structurées en python.

# %%
df = pd.DataFrame(dictionnaire)

# %%
df.head()
# Out:
#   Rank                                            Company        Location  \
# 0    1           RevolutDigital banking services provider     East London
# 1    2                      BizumaB2B e-commerce platform  Central London
# 2    3           Global-eCross-border ecommerce solutions  Central London
# 3    4  Jungle CreationsSocial media & ecommerce services     East London
# 4    5  Oxford Nanopore TechnologiesDNA analysis techn...          Oxford
#
#   Year end Annual sales rise over 3 years Latest sales £000s Staff  \
# 0   Dec 18                        507.56%            *58,300   700
# 1   Mar 19                        315.18%            *26,414   114
# 2   Dec 18                        303.09%             29,297    28
# 3   Dec 18                        302.53%            *15,972   159
# 4   Dec 18                        251.87%            *32,500   439
#
#                                              Comment
# 0  Valued at $1.7bn in 2018 and reported to be ra...
# 1  Connects wholesale buyers and sellers from ove...
# 2  Its technology helps ecommerce retailers local...
# 3  Launched the first-ever delivery-only restaura...
# 4  Has raised £451m in funding and was valued at ...

# %%
df['Latest sales £000s'] = df['Latest sales £000s'].str.replace('*', '')

# %%
df.head()
# Out:
#   Rank                                            Company        Location  \
# 0    1           RevolutDigital banking services provider     East London
# 1    2                      BizumaB2B e-commerce platform  Central London
# 2    3           Global-eCross-border ecommerce solutions  Central London
# 3    4  Jungle CreationsSocial media & ecommerce services     East London
# 4    5  Oxford Nanopore TechnologiesDNA analysis techn...          Oxford
#
#   Year end Annual sales rise over 3 years Latest sales £000s Staff  \
# 0   Dec 18                        507.56%             58,300   700
# 1   Mar 19                        315.18%             26,414   114
# 2   Dec 18                        303.09%             29,297    28
# 3   Dec 18                        302.53%             15,972   159
# 4   Dec 18                        251.87%             32,500   439
#
#                                              Comment
# 0  Valued at $1.7bn in 2018 and reported to be ra...
# 1  Connects wholesale buyers and sellers from ove...
# 2  Its technology helps ecommerce retailers local...
# 3  Launched the first-ever delivery-only restaura...
# 4  Has raised £451m in funding and was valued at ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
DATABASE_URI = 'postgres+psycopg2://enterprisedb:papaseye296@localhost:5444/test'

# %%
engine = create_engine(DATABASE_URI)

# %%
df.to_sql("Web_Scraping", engine.connect())
